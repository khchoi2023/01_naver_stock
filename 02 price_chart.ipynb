# %%
import mplfinance as mpf
import requests
import pandas as pd
import re
import time

# %%
test = pd.read_csv('003100.KQ.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='003100', type='line')

# %%
test = pd.read_csv('003380.KQ.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='003380', type='line')

# %%
test = pd.read_csv('004360.KS.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='004360', type='line')

# %%
test = pd.read_csv('004690.KS.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='004690', type='line')

# %%
test = pd.read_csv('016710.KS.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='016710', type='line')

# %%
test = pd.read_csv('017390.KS.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='017390', type='line')

# %%
test = pd.read_csv('030210.KS.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='030210', type='line')

# %%
test = pd.read_csv('032190.KQ.csv', encoding='cp949')
test.index = pd.DatetimeIndex(test['Date'])

mpf.plot(test, title='032190', type='line')
